# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import os

DATASET_PATH = os.path.join(os.getcwd(),'data','20230601_prof.nc')

data = xr.open_dataset(DATASET_PATH)
data
# Out:
# /home/rohith/Projects/Poseidon-RAG/.venv/bin/python: No module named pip
# <xarray.Dataset> Size: 6MB
# Dimensions:                       (N_PROF: 55, N_PARAM: 3, N_LEVELS: 1242,
#                                    N_CALIB: 2, N_HISTORY: 0)
# Dimensions without coordinates: N_PROF, N_PARAM, N_LEVELS, N_CALIB, N_HISTORY
# Data variables: (12/64)
#     DATA_TYPE                     object 8B ...
#     FORMAT_VERSION                object 8B ...
#     HANDBOOK_VERSION              object 8B ...
#     REFERENCE_DATE_TIME           object 8B ...
#     DATE_CREATION                 object 8B ...
#     DATE_UPDATE                   object 8B ...
#     ...                            ...
#     HISTORY_ACTION                (N_HISTORY, N_PROF) object 0B ...
#     HISTORY_PARAMETER             (N_HISTORY, N_PROF) object 0B ...
#     HISTORY_START_PRES            (N_HISTORY, N_PROF) float32 0B ...
#     HISTORY_STOP_PRES             (N_HISTORY, N_PROF) float32 0B ...
#     HISTORY_PREVIOUS_VALUE        (N_HISTORY, N_PROF) float32 0B ...
#     HISTORY_QCTEST                (N_HISTORY, N_PROF) object 0B ...
# Attributes:
#     title:                Argo float vertical profile
#     institution:          FR GDAC
#     source:               Argo float
#     history:              2026-06-03T06:53:33Z creation
#     references:           http://www.argodatamgt.org/Documentation
#     user_manual_version:  3.1
#     Conventions:          Argo-3.1 CF-1.6
#     featureType:          trajectoryProfile

# %%
list(data.data_vars)
# Out:
# ['DATA_TYPE',
#  'FORMAT_VERSION',
#  'HANDBOOK_VERSION',
#  'REFERENCE_DATE_TIME',
#  'DATE_CREATION',
#  'DATE_UPDATE',
#  'PLATFORM_NUMBER',
#  'PROJECT_NAME',
#  'PI_NAME',
#  'STATION_PARAMETERS',
#  'CYCLE_NUMBER',
#  'DIRECTION',
#  'DATA_CENTRE',
#  'DC_REFERENCE',
#  'DATA_STATE_INDICATOR',
#  'DATA_MODE',
#  'PLATFORM_TYPE',
#  'FLOAT_SERIAL_NO',
#  'FIRMWARE_VERSION',
#  'WMO_INST_TYPE',
#  'JULD',
#  'JULD_QC',
#  'JULD_LOCATION',
#  'LATITUDE',
#  'LONGITUDE',
#  'POSITION_QC',
#  'POSITIONING_SYSTEM',
#  'PROFILE_PRES_QC',
#  'PROFILE_TEMP_QC',
#  'PROFILE_PSAL_QC',
#  'VERTICAL_SAMPLING_SCHEME',
#  'CONFIG_MISSION_NUMBER',
#  'PRES',
#  'PRES_QC',
#  'PRES_ADJUSTED',
#  'PRES_ADJUSTED_QC',
#  'PRES_ADJUSTED_ERROR',
#  'TEMP',
#  'TEMP_QC',
#  'TEMP_ADJUSTED',
#  'TEMP_ADJUSTED_QC',
#  'TEMP_ADJUSTED_ERROR',
#  'PSAL',
#  'PSAL_QC',
#  'PSAL_ADJUSTED',
#  'PSAL_ADJUSTED_QC',
#  'PSAL_ADJUSTED_ERROR',
#  'PARAMETER',
#  'SCIENTIFIC_CALIB_EQUATION',
#  'SCIENTIFIC_CALIB_COEFFICIENT',
#  'SCIENTIFIC_CALIB_COMMENT',
#  'SCIENTIFIC_CALIB_DATE',
#  'HISTORY_INSTITUTION',
#  'HISTORY_STEP',
#  'HISTORY_SOFTWARE',
#  'HISTORY_SOFTWARE_RELEASE',
#  'HISTORY_REFERENCE',
#  'HISTORY_DATE',
#  'HISTORY_ACTION',
#  'HISTORY_PARAMETER',
#  'HISTORY_START_PRES',
#  'HISTORY_STOP_PRES',
#  'HISTORY_PREVIOUS_VALUE',
#  'HISTORY_QCTEST']

# %%
essential_vars = ['PLATFORM_NUMBER', 'LATITUDE', 'LONGITUDE', 'JULD', 'PRES', 'TEMP', 'PSAL']

df = data[essential_vars].to_dataframe().reset_index()
df
# Out:
#        N_PROF  N_LEVELS PLATFORM_NUMBER  LATITUDE  LONGITUDE  \
# 0           0         0     b'1902482 '   0.98644   65.20156
# 1           0         1     b'1902482 '   0.98644   65.20156
# 2           0         2     b'1902482 '   0.98644   65.20156
# 3           0         3     b'1902482 '   0.98644   65.20156
# 4           0         4     b'1902482 '   0.98644   65.20156
# ...       ...       ...             ...       ...        ...
# 68305      54      1237     b'1902473 '  -2.98064   63.81826
# 68306      54      1238     b'1902473 '  -2.98064   63.81826
# 68307      54      1239     b'1902473 '  -2.98064   63.81826
# 68308      54      1240     b'1902473 '  -2.98064   63.81826
# 68309      54      1241     b'1902473 '  -2.98064   63.81826
#
#                      JULD  PRES       TEMP       PSAL
# 0     2023-06-01 23:56:49  1.12  30.127001  34.835999
# 1     2023-06-01 23:56:49  2.00  30.132999  34.834000
# 2     2023-06-01 23:56:49  3.00  30.135000  34.833000
# 3     2023-06-01 23:56:49  4.00  30.129000  34.831001
# 4     2023-06-01 23:56:49  4.96  30.136000  34.830002
# ...                   ...   ...        ...        ...
# 68305 2023-06-01 01:15:38   NaN        NaN        NaN
# 68306 2023-06-01 01:15:38   NaN        NaN        NaN
# 68307 2023-06-01 01:15:38   NaN        NaN        NaN
# 68308 2023-06-01 01:15:38   NaN        NaN        NaN
# 68309 2023-06-01 01:15:38   NaN        NaN        NaN
#
# [68310 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 68310 entries, 0 to 68309
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   N_PROF           68310 non-null  int64
#  1   N_LEVELS         68310 non-null  int64
#  2   PLATFORM_NUMBER  68310 non-null  object
#  3   LATITUDE         68310 non-null  float64
#  4   LONGITUDE        68310 non-null  float64
#  5   JULD             68310 non-null  datetime64[ns]
#  6   PRES             35562 non-null  float32
#  7   TEMP             35562 non-null  float32
#  8   PSAL             35562 non-null  float32
# dtypes: datetime64[ns](1), float32(3), float64(2), int64(2), object(1)
# memory usage: 3.9+ MB

# %%
cleaned_df = df.dropna()

# %%
import sqlite3

conn = sqlite3.connect('data/argo_data.db')

#Table name :"measurements" conn, if_exists="replace", index=False
cleaned_df.to_sql(name='measurements',con=conn,if_exists='replace',index=False)

print('Rows added to DB')
# Out:
# Rows added to DB

# %%
query = '''
    SELECT 
        Platform_number,
        COUNT(*) as total_readings,
        ROUND(MIN(temp), 2) as min_temp,
        ROUND(MAX(temp), 2) as max_temp,
        ROUND(AVG(latitude), 4) as avg_lat,
        ROUND(AVG(longitude), 4) as avg_lon
    FROM measurements
    GROUP BY Platform_number
'''

cursor = conn.cursor()
cursor.execute(query)

rows = cursor.fetchall()

for row in rows :
    print(f"Float #{row[0].decode().strip()} took {row[1]} readings. Temp range: {row[2]}°C to {row[3]}°C. Location: ({row[4]}, {row[5]})")
# Out:
# Float #1901743 took 995 readings. Temp range: 0.59°C to 1.97°C. Location: (-54.6967, 79.1357)
# Float #1901809 took 1012 readings. Temp range: 2.46°C to 12.54°C. Location: (-40.2299, 121.9377)
# Float #1901843 took 1010 readings. Temp range: 2.4°C to 27.43°C. Location: (-14.7126, 68.8273)
# Float #1901897 took 54 readings. Temp range: 3.22°C to 30.43°C. Location: (16.7665, 55.1972)
# Float #1902043 took 1012 readings. Temp range: 2.76°C to 19.37°C. Location: (-35.145, 47.9535)
# Float #1902222 took 1010 readings. Temp range: 2.65°C to 16.44°C. Location: (-38.4063, 69.8896)
# Float #1902259 took 1012 readings. Temp range: 2.57°C to 17.54°C. Location: (-36.2464, 62.9334)
# Float #1902292 took 1008 readings. Temp range: 0.61°C to 1.84°C. Location: (-55.9838, 48.396)
# Float #1902294 took 1012 readings. Temp range: 0.43°C to 1.84°C. Location: (-57.3648, 34.1121)
# Float #1902453 took 510 readings. Temp range: 2.81°C to 30.05°C. Location: (-0.9638, 64.6365)
# Float #1902472 took 501 readings. Temp range: 7.67°C to 30.44°C. Location: (-0.0048, 64.8185)
# Float #1902473 took 497 readings. Temp range: 6.83°C to 29.59°C. Location: (-2.9806, 63.8183)
# Float #1902482 took 549 readings. Temp range: 7.14°C to 30.2°C. Location: (0.9876, 65.2024)
# Float #2903142 took 1012 readings. Temp range: 3.22°C to 31.95°C. Location: (15.1578, 60.9085)
# Float #3901229 took 500 readings. Temp range: 7.35°C to 16.38°C. Location: (-42.2191, 63.2022)
# Float #3901829 took 416 readings. Temp range: 4.99°C to 15.04°C. Location: (-40.0836, 35.2373)
# Float #3902471 took 193 readings. Temp range: 7.76°C to 28.43°C. Location: (-6.0245, 61.2091)
# Float #4903633 took 1003 readings. Temp range: 2.53°C to 18.37°C. Location: (-34.7484, 53.8593)
# Float #5902483 took 1008 readings. Temp range: 2.57°C to 17.42°C. Location: (-34.9245, 110.0096)
# Float #5902502 took 1008 readings. Temp range: 2.55°C to 18.88°C. Location: (-32.0765, 105.0878)
# Float #5902504 took 553 readings. Temp range: 3.56°C to 18.8°C. Location: (-32.9605, 112.1169)
# Float #5904807 took 506 readings. Temp range: 2.21°C to 7.31°C. Location: (-52.033, 144.585)
# Float #5904827 took 508 readings. Temp range: 2.6°C to 26.09°C. Location: (-18.381, 84.856)
# Float #5905384 took 948 readings. Temp range: 2.46°C to 15.9°C. Location: (-36.7891, 103.6779)
# Float #5905385 took 947 readings. Temp range: 2.53°C to 24.58°C. Location: (-22.3989, 87.9447)
# Float #5905417 took 1002 readings. Temp range: 2.41°C to 27.78°C. Location: (-14.1371, 118.5045)
# Float #5905428 took 1003 readings. Temp range: 2.41°C to 25.4°C. Location: (-24.4158, 58.3041)
# Float #5905521 took 997 readings. Temp range: 2.57°C to 28.06°C. Location: (-11.8971, 107.2749)
# Float #5905875 took 920 readings. Temp range: 1.24°C to 12.29°C. Location: (-41.645, 97.518)
# Float #5906030 took 499 readings. Temp range: 2.45°C to 11.75°C. Location: (-44.627, 92.863)
# Float #5906149 took 1012 readings. Temp range: 2.57°C to 10.27°C. Location: (-44.3693, 126.3695)
# Float #5906207 took 496 readings. Temp range: 2.46°C to 6.23°C. Location: (-51.788, 124.457)
# Float #5906266 took 509 readings. Temp range: 2.63°C to 28.66°C. Location: (-13.455, 95.598)
# Float #5906274 took 509 readings. Temp range: 2.52°C to 27.11°C. Location: (-12.906, 89.121)
# Float #5906287 took 509 readings. Temp range: 2.55°C to 14.78°C. Location: (-37.565, 106.18)
# Float #5906628 took 1000 readings. Temp range: 2.48°C to 10.88°C. Location: (-43.4739, 125.4392)
# Float #6902782 took 61 readings. Temp range: -0.89°C to 1.95°C. Location: (-62.399, 80.958)
# Float #6903045 took 1000 readings. Temp range: 2.78°C to 17.62°C. Location: (-39.7524, 49.3379)
# Float #6903059 took 588 readings. Temp range: 10.35°C to 29.83°C. Location: (22.5344, 65.3596)
# Float #6903060 took 595 readings. Temp range: 10.94°C to 29.28°C. Location: (20.0598, 60.593)
# Float #6903151 took 1012 readings. Temp range: 2.51°C to 19.2°C. Location: (-31.6983, 93.8605)
# Float #6904066 took 407 readings. Temp range: 1.28°C to 2.4°C. Location: (-53.1199, 38.536)
# Float #6904068 took 407 readings. Temp range: 1.07°C to 2.31°C. Location: (-54.3135, 41.7816)
# Float #6904069 took 284 readings. Temp range: 1.09°C to 2.27°C. Location: (-53.5692, 44.127)
# Float #6904077 took 404 readings. Temp range: 2.62°C to 18.33°C. Location: (-39.3, 26.0603)
# Float #6990503 took 223 readings. Temp range: 6.74°C to 29.2°C. Location: (-3.5872, 60.1238)
# Float #7900110 took 561 readings. Temp range: -0.63°C to 1.99°C. Location: (-60.8436, 53.1031)
# Float #7900511 took 96 readings. Temp range: 1.4°C to 2.38°C. Location: (-57.6251, 64.7216)
# Float #7900512 took 97 readings. Temp range: 2.5°C to 11.63°C. Location: (-42.7107, 104.0397)
# Float #7900910 took 997 readings. Temp range: 0.32°C to 1.92°C. Location: (-59.0849, 102.2496)
# Float #7900939 took 998 readings. Temp range: -1.71°C to 1.28°C. Location: (-64.458, 109.3379)
# Float #7900940 took 2 readings. Temp range: -1.51°C to -1.5°C. Location: (-66.4065, 108.7902)
# Float #7901002 took 590 readings. Temp range: 1.98°C to 3.95°C. Location: (-51.4119, 70.1904)
